# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_values = np.linspace(0,2,100)

y_values = x_values**2

plt.figure(figsize=(12,8))
plt.plot(x_values,y_values)
plt.plot(x_values,x_values)
plt.gca().invert_xaxis()

plt.title("Squared Function and linear Function")
plt.show()

# %%
x = np.linspace(0,10,1000)
y = np.random.uniform(0,10,1000)

plt.scatter(x,y)

# %%
x= np.random.uniform(0,1,(10,10))

plt.imshow(x,cmap='Blues')
print(x)
# Out:
# [[4.34852646e-01 6.98689425e-01 5.68896290e-01 2.20739549e-02
#   7.73402289e-01 6.26370398e-01 1.91879117e-03 9.93919212e-01
#   6.36198435e-02 5.35440815e-01]
#  [1.87182564e-01 4.79243163e-01 1.16983369e-02 5.23794660e-01
#   5.00354460e-01 6.47224191e-01 2.70069159e-01 7.30263785e-01
#   7.51139990e-01 8.33168157e-01]
#  [7.24778612e-01 9.59112072e-01 2.52424788e-01 9.44335799e-01
#   7.74338995e-01 6.54277863e-01 7.92914188e-01 5.06560716e-01
#   6.88344939e-01 4.03020851e-01]
#  [7.52588317e-01 1.29506314e-02 6.44907673e-01 8.34905196e-01
#   3.80976841e-01 4.45567767e-01 2.96580520e-01 7.06142468e-01
#   3.25494583e-01 6.25663903e-01]
#  [7.29940919e-01 8.64176643e-01 7.79362161e-04 7.62128636e-01
#   7.58883297e-01 4.56778248e-01 7.80722694e-01 1.62654098e-01
#   3.93320620e-01 3.49825435e-02]
#  [9.70165279e-01 2.14814155e-01 3.11008423e-01 9.78812292e-02
#   9.74911091e-01 8.37561517e-01 1.09759914e-01 2.19253884e-01
#   2.79038327e-01 3.94278154e-01]
#  [4.90400809e-01 3.85032691e-01 8.31318210e-01 2.82476066e-01
#   1.22198676e-02 4.58909193e-01 2.92900133e-01 3.46930281e-01
#   7.95460303e-01 4.05685393e-01]
#  [4.94956219e-01 6.64326955e-01 9.25103661e-01 5.37517090e-01
#   5.83265809e-01 6.69442305e-01 5.37928287e-01 7.55955644e-01
#   4.66507593e-01 8.84246719e-01]
#  [1.87590686e-01 9.21706114e-01 1.33455739e-01 2.61330439e-01
#   2.41041650e-01 3.85034667e-01 3.65571489e-01 2.33106682e-01
#   3.86647333e-01 7.15629898e-01]
#  [1.75945954e-01 2.80964833e-01 1.36084767e-01 8.44409250e-01
#   5.96953258e-01 1.48935250e-01 8.55827313e-01 3.04966183e-01
#   8.98311228e-01 4.68321288e-01]]

# %%
import matplotlib.pyplot as plt
import numpy as np
z=np.random.uniform(0,1,(10,10))
x=np.random.uniform(0,1,(10,10))

fig,axs=plt.subplots(2,2,figsize=(5,5),layout="constrained")
axs[0,0].imshow(z,cmap="Blues")
axs[0,1].contourf(z,cmap="Blues")
axs[1,0].boxplot(x )
axs[1,1].violinplot(x,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x16d5d2606b0>,
#   <matplotlib.collections.PolyCollection at 0x16d5c9f0590>,
#   <matplotlib.collections.PolyCollection at 0x16d5d1b93a0>,
#   <matplotlib.collections.PolyCollection at 0x16d5d260740>,
#   <matplotlib.collections.PolyCollection at 0x16d5c9f2a50>,
#   <matplotlib.collections.PolyCollection at 0x16d5c9f2870>,
#   <matplotlib.collections.PolyCollection at 0x16d5c9f3200>,
#   <matplotlib.collections.PolyCollection at 0x16d5c9f2f60>,
#   <matplotlib.collections.PolyCollection at 0x16d5d1e64e0>,
#   <matplotlib.collections.PolyCollection at 0x16d5c9cac00>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x16d5c9f1670>,
#  'cmins': <matplotlib.collections.LineCollection at 0x16d5c9f0ad0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x16d5c9c9610>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x16d5c9f26f0>}

# %%
x= np.linspace(-2*np.pi,2*np.pi,30)
y= np.sin(x)

plt.figure(figsize=(5,5),layout="constrained")
plt.stem(x,y)
# Out:
# <StemContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np


t = np.linspace(0, 5, 1000) 
f = 1  
damped_sine_wave = np.exp(-t) * np.sin(2 * np.pi * f * t)
upper_envelope = np.exp(-t)
lower_envelope = -np.exp(-t)
plt.figure(figsize=(10, 5))
plt.plot(t, damped_sine_wave, color='black', label=r'$e^{-t} \sin(2\pi f t)$')
plt.plot(t, upper_envelope, 'r--', label='Upper Envelope: $e^{-t}$')
plt.plot(t, lower_envelope, 'r--', label='Lower Envelope: $-e^{-t}$')
plt.title(r'$e^{-t} \sin(2\pi f t)$ with Envelopes')
plt.xlabel('t')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x and y arrays
x = np.linspace(-2, 2, 50)
y = np.exp(x)

# Modify y values: Invert every second element
for i in range(len(y)):
    if (i + 1) % 2 == 0:  # Using (i + 1) to count from 1
        y[i] = -y[i]

print(y)

# Plot the results
plt.figure(figsize=(5,5), layout="constrained")
plt.stem(-x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Stem Plot with Modified y Values')
plt.show()
# Out:
# [ 0.13533528 -0.14684652  0.15933686 -0.1728896   0.1875951  -0.2035514
#   0.2208649  -0.23965104  0.26003507 -0.28215291  0.30615203 -0.33219245
#   0.36044779 -0.39110645  0.42437285 -0.46046879  0.49963495 -0.54213247
#   0.58824471 -0.63827912  0.69256932 -0.75147729  0.81539581 -0.88475104
#   0.96000544 -1.04166076  1.13026145 -1.22639826  1.3307122  -1.44389878
#   1.56671268 -1.69997279  1.84456762 -2.00146127  2.17169985 -2.35641844
#   2.55684867 -2.77432691  3.01030324 -3.26635103  3.54417752 -3.84563514
#   4.17273388 -4.52765471  4.91276409 -5.33062977  5.78403792 -6.27601167
#   6.8098313  -7.3890561 ]

# %%
import numpy as np
import matplotlib.pyplot as plt
